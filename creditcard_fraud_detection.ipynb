# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from imblearn.under_sampling import RandomUnderSampler

# Load Dataset
df = pd.read_csv('/content/fraudTest.csv')

# Data Preprocessing
df.drop(['Unnamed: 0', 'first', 'last', 'street', 'trans_num', 'trans_date_trans_time'], axis=1, inplace=True)

# Encode Categorical Features
df = pd.get_dummies(df, drop_first=True)

# Feature-Target Split
X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

# Handle Missing Values in Target
y.dropna(inplace=True)
X = X.loc[y.index]  # Ensure X matches y's updated index

# Handle Class Imbalance
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=42)

# Initialize Models
models = {
    'RandomForest': RandomForestClassifier(n_estimators=100, random_state=42),
    'XGBoost': XGBClassifier(n_estimators=100, random_state=42),
    'GradientBoosting': GradientBoostingClassifier(n_estimators=100, random_state=42)
}

# Evaluate Models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{name} Results:")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(f"Precision: {precision_score(y_test, y_pred):.2f}")
    print(f"Recall: {recall_score(y_test, y_pred):.2f}")
    print(f"F1 Score: {f1_score(y_test, y_pred):.2f}")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("-"*50)
# Out:
# RandomForest Results:
# Accuracy: 0.93
# Precision: 0.94
# Recall: 0.92
# F1 Score: 0.93
# [[625  35]
#  [ 53 574]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       660
#            1       0.94      0.92      0.93       627
#
#     accuracy                           0.93      1287
#    macro avg       0.93      0.93      0.93      1287
# weighted avg       0.93      0.93      0.93      1287
#
# --------------------------------------------------
# XGBoost Results:
# Accuracy: 0.96
# Precision: 0.95
# Recall: 0.97
# F1 Score: 0.96
# [[630  30]
#  [ 18 609]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       660
#            1       0.95      0.97      0.96       627
#
#     accuracy                           0.96      1287
#    macro avg       0.96      0.96      0.96      1287
# weighted avg       0.96      0.96      0.96      1287
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from imblearn.under_sampling import RandomUnderSampler

# Load Dataset
df = pd.read_csv('/content/fraudTest.csv')

# Data Preprocessing
df.drop(['Unnamed: 0', 'first', 'last', 'street', 'trans_num', 'trans_date_trans_time'], axis=1, inplace=True)

# Encode Categorical Features
df = pd.get_dummies(df, drop_first=True)

# Feature-Target Split
X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

# Handle Missing Values in Target
y.dropna(inplace=True)
X = X.loc[y.index]  # Ensure X matches y's updated index

# Handle Class Imbalance
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=42)

# Initialize Model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Prediction for Custom Input
def predict_transaction():
    print("Enter transaction details:")
    input_data = []
    for feature in X.columns:
        value = float(input(f"{feature}: "))
        input_data.append(value)

    prediction = model.predict([input_data])[0]
    result = "Fraudulent Transaction" if prediction == 1 else "Not a Fraudulent Transaction"
    print(f"Prediction: {result}")

# Run Prediction
predict_transaction()
# Out:
# Enter transaction details:
# cc_num: 2291163933867244
# amt: 2.86
# zip: 29209
# lat: 33.9659
# long: -80.9355
# city_pop: 333497
# unix_time: 1371816865
# merch_lat: 33.986391
# merch_long: -81.200714
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c32409b57420> in <cell line: 0>()
#      48
#      49 # Run Prediction
# ---> 50 predict_transaction()
#
# <ipython-input-17-c32409b57420> in predict_transaction()
#      40     input_data = []
#      41     for feature in X.columns:
# ---> 42         value = float(input(f"{feature}: "))
#      43         input_data.append(value)
#      44
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
# ...

# %%
# prompt: i want to see complete columns of the datstet

pd.set_option("display.max_columns", None)
df
# Out:
#                   cc_num     amt    zip      lat      long  city_pop  \
# 0       2291163933867244    2.86  29209  33.9659  -80.9355    333497
# 1       3573030041201292   29.84  84002  40.3207 -110.4360       302
# 2       3598215285024754   41.28  11710  40.6729  -73.5365     34496
# 3       3591919803438423   60.05  32780  28.5697  -80.8191     54767
# 4       3526826139003047    3.19  49632  44.2529  -85.0170      1126
# ...                  ...     ...    ...      ...       ...       ...
# 555714    30560609640617   43.77  63453  40.4931  -91.8912       519
# 555715  3556613125071656  111.84  77566  29.0393  -95.4401     28739
# 555716  6011724471098086   86.88  99323  46.1966 -118.9017      3684
# 555717     4079773899158    7.99  83643  44.6255 -116.4493       129
# 555718  4170689372027579   38.13  73034  35.6665  -97.4798    116001
#
#          unix_time  merch_lat  merch_long  is_fraud  \
# 0       1371816865  33.986391  -81.200714         0
# ...
